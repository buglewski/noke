# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt

# %matplotlib inline
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6060\4213999422.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
class ApsundNokeModel():
    def __init__(self, distr, data, n_depth = 20000):
        self.distr = distr
        self.setData(data)
        self.n_depth = n_depth
    
    def setData(self, data):
        self.data = data
        self.n_epochs = data.shape[0]
        self.k_params = 0
        for x in self.data.columns:
            if x[0:5] == "param":
                self.k_params+=1

    def getParams(self, epoch):
        params = (self.data[f"param_0"][epoch],)
        for i in range(1, self.k_params):
            params += (self.data[f"param_{i}"][epoch],)
        return params
        
    
    def Sigma2(self, C, epoch):
        sigma = self.data["sigma"][epoch]
        return (1+sigma*np.sum(C))/(1+sigma*len(C))
    
    def expectedProfit_montecarlo(self, C, epoch, sigma2 = None):
        f = self.data["f"][epoch]
        S = self.data["S"][epoch]
        params = self.getParams(epoch)
        n = self.n_depth
        if sigma2 == None:
            sigma2 = self.Sigma2(C, epoch)
        if self.distr == np.random.uniform:
            a, b = params[0], params[1]
            if sigma2 > b:
                return S*0.125*(sigma2**2-sigma2*(b+a)+1/3*(b**2+b*a+a**2))-f
            if sigma2 < a:
                return -f
            return S * 1/24*(sigma2-a)**3/(b-a)-f
        
        answ = 0
        for i in range(n):
            cc = np.abs(self.distr(*params))
            answ -= f
            if cc<= sigma2:
                answ += S * 1/8*(sigma2-cc)**2
        return answ/n

    def NPV_for_entrant(self, C, epoch, sigma2 = None):
        r = self.data["r"][epoch]
        return ((1+r)/r) * self.expectedProfit_montecarlo(C, epoch, sigma2)
    
    def scenario(self, out = False):
        #data prepare
        NPV_ent = [0] * self.n_epochs
        M = [0] * self.n_epochs
        P_mean = [0] * self.n_epochs
        EP_ = [0] * self.n_epochs
        C_mean = [0] * self.n_epochs
        C_max = [0] * self.n_epochs
        Sigma2 = [0] * self.n_epochs
        M_ent = [0] * self.n_epochs
        M_ex = [0] * self.n_epochs

        #zero epoch
        params = self.getParams(0)
        C = np.abs(self.distr(*params, size = 10))
        
        for epoch in range(self.n_epochs):
            #loading data
            params = self.getParams(epoch)
            f = self.data["f"][epoch]
            r = self.data["r"][epoch]
            ef = self.data["ef"][epoch]
            alpha = self.data["alpha"][epoch]
            sigma = self.data["sigma"][epoch]
            S = self.data["S"][epoch]

            NPV1 = self.NPV_for_entrant(C, epoch)
            EP = self.expectedProfit_montecarlo(C, epoch)

            #entrance stage
            if epoch == 0:
                cmax = np.max(C)
            else:
                cmax = C_max[epoch-1]
            cmean = np.mean(C_mean[:epoch+1])

            n_ent = 0
            while NPV1 > ef:
                #c = np.abs(self.distr(*params, size = 1))
                #C = np.append(C, c)
                n_ent += 1
                params = self.getParams(epoch)
                a, b = params[0], params[1]
                sigma2 = (1+ sigma * (np.sum(C)+ n_ent * (cmax-a)/(b-a)*cmean))/(1+sigma*(len(C)+ n_ent*(cmax-a)/(b-a)))
                NPV1 = self.NPV_for_entrant(C, epoch, sigma2)

            c = np.abs(self.distr(*params, size = n_ent))
            C = np.append(C, c)

            #recounting stage
            for i in range(len(C)):
                a = random.random()
                if a > alpha:
                    C[i] = np.abs(self.distr(*params))
            
            # sort of C
            C = np.flip(np.sort(C))

            # exit stage
            EP = self.expectedProfit_montecarlo(C, epoch)
            sigma2 = self.Sigma2(C, epoch)
            n_ex = 0
            i = 0
            P_fact = []
            while (i < len(C)):
                P = - f
                if sigma2 > C[i]:
                    P = S * 1/8*(sigma2 - C[i])**2 - f
                P_fact.append(P)
                NPV2 = (1+r)/(1+r-alpha) * P + (1/r - alpha/(1+r-alpha))*EP
                if NPV2 < 0:
                    C = np.delete(C, i)
                    n_ex += 1
                    EP = self.expectedProfit_montecarlo(C, epoch)
                    sigma2 = self.Sigma2(C, epoch)
                else:
                    i += 1
                
            NPV_ent[epoch] = NPV1
            M[epoch] = len(C)
            P_mean[epoch] = np.mean(P_fact)
            EP_[epoch] = EP
            C_mean[epoch] = np.mean(C)
            C_max[epoch] = np.max(C)
            Sigma2[epoch] = sigma2
            M_ent[epoch] = n_ent
            M_ex[epoch] = n_ex

            if out:
                print(f"epoch{epoch}, number of firms: {M[epoch]}, entrats: {M_ent[epoch]}, exiters: {M_ex[epoch]}, EP: {EP_[epoch]}, C_mean: {C_mean[epoch]}, EP_fact: {P_mean[epoch]}")
        
        self.data["NPV_ent"] = NPV_ent
        self.data["n_firms"] = M
        self.data["Pr_mean"] = P_mean
        self.data["EP"] = EP_
        self.data["C_mean"] = C_mean
        self.data["C_max"] = C_max
        self.data["Sigma2"] = Sigma2
        self.data["n_entr"] = M_ent
        self.data["n_ext"] = M_ex

    def getData(self):
        return self.data

# %%
#parameters of distribution
Ec = 0.2
Dc = 0.01
scale = Dc**0.5

#parameters of utility
sigma = 0.5
S = 16

#parameters of firms
f = 0.01 # fixed costs
ef = 0.01 # entrance costs
r = 0.01 #return of interest
alpha = 0.8
a=0.1
b=0.2

n = 200

data = {"param_0": [a]*n,
        "param_1": [b]*n,
        "sigma": [sigma]*n,
        "S": [S]*n,
        "f": [f]*n,
        "ef": [ef]*n,
        "r": [r]*n,
        "alpha": [alpha]*n}

df = pd.DataFrame(data)
df
# Out:
#      param_0  param_1  sigma   S     f    ef     r  alpha
# 0        0.1      0.2    0.5  16  0.01  0.01  0.01    0.8
# 1        0.1      0.2    0.5  16  0.01  0.01  0.01    0.8
# 2        0.1      0.2    0.5  16  0.01  0.01  0.01    0.8
# 3        0.1      0.2    0.5  16  0.01  0.01  0.01    0.8
# 4        0.1      0.2    0.5  16  0.01  0.01  0.01    0.8
# ..       ...      ...    ...  ..   ...   ...   ...    ...
# 195      0.1      0.2    0.5  16  0.01  0.01  0.01    0.8
# 196      0.1      0.2    0.5  16  0.01  0.01  0.01    0.8
# 197      0.1      0.2    0.5  16  0.01  0.01  0.01    0.8
# 198      0.1      0.2    0.5  16  0.01  0.01  0.01    0.8
# 199      0.1      0.2    0.5  16  0.01  0.01  0.01    0.8
#
# [200 rows x 8 columns]

# %%
Noke = ApsundNokeModel(distr = np.random.uniform,
                       data = df)

# %%
Noke.scenario(out=True)
# Out:
# epoch0, number of firms: 15, entrats: 5, exiters: 0, EP: 0.014165677522734498, C_mean: 0.15687217714678478, EP_fact: 0.010934239966636235
# epoch1, number of firms: 21, entrats: 6, exiters: 0, EP: 0.0031508257008853336, C_mean: 0.15204093988030043, EP_fact: 0.00267391184536653
# epoch2, number of firms: 23, entrats: 3, exiters: 1, EP: 0.0005267883862330614, C_mean: 0.14843337212991334, EP_fact: 0.0002955516925212184
# epoch3, number of firms: 24, entrats: 1, exiters: 0, EP: 0.0005449719102325352, C_mean: 0.15134588002371616, EP_fact: -0.00025392169480619565
# epoch4, number of firms: 21, entrats: 1, exiters: 4, EP: 0.0005283099338236081, C_mean: 0.14195150452278735, EP_fact: 0.0004920470284591171
# epoch5, number of firms: 19, entrats: 1, exiters: 3, EP: 0.0005916596922727491, C_mean: 0.13436001681825216, EP_fact: 0.0028674119334435237
# epoch6, number of firms: 20, entrats: 1, exiters: 0, EP: 0.001844097168158131, C_mean: 0.14346875463139674, EP_fact: 0.0034057865153848607
# epoch7, number of firms: 19, entrats: 2, exiters: 3, EP: 0.0007065767872977569, C_mean: 0.13483383325065795, EP_fact: 0.002829041451024895
# epoch8, number of firms: 17, entrats: 1, exiters: 3, EP: 0.0006034579929461315, C_mean: 0.12471030173110267, EP_fact: 0.005472732274424039
# epoch9, number of firms: 18, entrats: 1, exiters: 0, EP: 0.0012579649639077473, C_mean: 0.13250069513220342, EP_fact: 0.006084373096326114
# epoch10, number of firms: 20, entrats: 2, exiters: 0, EP: 0.000698529919880066, C_mean: 0.13892074991634024, EP_fact: 0.0036041741433888025
# epoch11, number of firms: 18, entrats: 1, exiters: 3, EP: 0.0008326194910486962, C_mean: 0.1307752043888637, EP_fact: 0.0038977221898270327
# epoch12, number of firms: 18, entrats: 1, exiters: 1, EP: 0.0009217980370793011, C_mean: 0.13114023691236404, EP_fact: 0.005272520521074002
# epoch13, number of firms: 20, entrats: 2, exiters: 0, EP: 0.001577145369077092, C_mean: 0.1424328070972396, EP_fact: 0.003289924240920012
# epoch14, number of firms: 19, entrats: 2, exiters: 3, EP: 0.0003876937545706522, C_mean: 0.13351146725780658, EP_fact: 0.0026500010606073866
# epoch15, number of firms: 18, entrats: 1, exiters: 2, EP: 0.000730030401112235, C_mean: 0.13035307537994534, EP_fact: 0.0042516342243395875
# epoch16, number of firms: 19, entrats: 1, exiters: 0, EP: 0.000639939788236692, C_mean: 0.1345594506056469, EP_fact: 0.0045464764623588325
# epoch17, number of firms: 20, entrats: 1, exiters: 0, EP: 0.0007946196676911644, C_mean: 0.13931293000292638, EP_fact: 0.003354020549158024
# epoch18, number of firms: 21, entrats: 1, exiters: 0, EP: 0.0007839256636884718, C_mean: 0.14299549252985538, EP_fact: 0.002307332956963079
# epoch19, number of firms: 20, entrats: 1, exiters: 2, EP: 0.0005484278437485769, C_mean: 0.13830392562567556, EP_fact: 0.002021314085257856
# epoch20, number of firms: 21, entrats: 1, exiters: 0, EP: 0.0017017191835268248, C_mean: 0.14662826088566677, EP_fact: 0.002170803693524727
# epoch21, number of firms: 19, entrats: 2, exiters: 4, EP: 0.0006002515131555159, C_mean: 0.13439554700492842, EP_fact: 0.001921457536761561
# epoch22, number of firms: 20, entrats: 1, exiters: 0, EP: 0.0018632685268689265, C_mean: 0.1435426261683577, EP_fact: 0.0030059310149953525
# epoch23, number of firms: 20, entrats: 3, exiters: 3, EP: 0.00035403531174073473, C_mean: 0.1374972967100831, EP_fact: 0.0015030255084261803
# epoch24, number of firms: 19, entrats: 1, exiters: 2, EP: 0.00018307686433492905, C_mean: 0.13265017909512697, EP_fact: 0.0032625313938341636
# epoch25, number of firms: 19, entrats: 1, exiters: 1, EP: 0.0003278348706550766, C_mean: 0.13326056033482497, EP_fact: 0.0035776187126676947
# epoch26, number of firms: 19, entrats: 1, exiters: 1, EP: 0.0006867401297307053, C_mean: 0.1347522604103624, EP_fact: 0.0036236680996063523
# epoch27, number of firms: 19, entrats: 1, exiters: 1, EP: 0.0006402699386534889, C_mean: 0.1345608125303965, EP_fact: 0.003629458772289048
# epoch28, number of firms: 18, entrats: 1, exiters: 2, EP: 0.0007103650303364756, C_mean: 0.13027188478897797, EP_fact: 0.004709330631160554
# epoch29, number of firms: 19, entrats: 1, exiters: 0, EP: 0.0004062044625798445, C_mean: 0.13358888306464511, EP_fact: 0.0044871417162105276
# epoch30, number of firms: 20, entrats: 1, exiters: 0, EP: 0.0014676162294603601, C_mean: 0.14200373033490132, EP_fact: 0.0037997495743951684
# epoch31, number of firms: 18, entrats: 2, exiters: 4, EP: 0.0008260144387452362, C_mean: 0.1307480975914934, EP_fact: 0.0034608260791935243
# epoch32, number of firms: 19, entrats: 1, exiters: 0, EP: 0.0008456280218775442, C_mean: 0.1354031487055747, EP_fact: 0.005030248452422339
# epoch33, number of firms: 20, entrats: 1, exiters: 0, EP: 0.0010311957706888048, C_mean: 0.14026978217009403, EP_fact: 0.003552205841391428
# epoch34, number of firms: 20, entrats: 1, exiters: 1, EP: 0.0006154443394876408, C_mean: 0.13857995985359534, EP_fact: 0.002848269992612242
# epoch35, number of firms: 20, entrats: 1, exiters: 1, EP: 0.0006045457862627213, C_mean: 0.1385351403572171, EP_fact: 0.0028711751419712175
# epoch36, number of firms: 21, entrats: 1, exiters: 0, EP: 0.0016436501588845426, C_mean: 0.14640347041516172, EP_fact: 0.0024046963825036186
# epoch37, number of firms: 23, entrats: 2, exiters: 0, EP: 0.0012744692925456286, C_mean: 0.15142411074462567, EP_fact: 0.0005546069234760232
# epoch38, number of firms: 25, entrats: 2, exiters: 0, EP: 0.0005928471081771847, C_mean: 0.15415087271467298, EP_fact: -0.0010428560597320888
# epoch39, number of firms: 26, entrats: 1, exiters: 0, EP: 0.0012126116037878432, C_mean: 0.15901644889476577, EP_fact: -0.0016461603092764775
# epoch40, number of firms: 25, entrats: 2, exiters: 3, EP: 0.0004594641063626632, C_mean: 0.15360977214620028, EP_fact: -0.001977782351609405
# epoch41, number of firms: 21, entrats: 1, exiters: 5, EP: 0.0006970419465828093, C_mean: 0.14264230271298034, EP_fact: 8.978870462346057e-05
# epoch42, number of firms: 22, entrats: 1, exiters: 0, EP: 0.0008643147443342398, C_mean: 0.14670686906514552, EP_fact: 0.0014075681714120784
# epoch43, number of firms: 19, entrats: 1, exiters: 4, EP: 0.0003123229520605609, C_mean: 0.13319539861114046, EP_fact: 0.0021424332405092362
# epoch44, number of firms: 19, entrats: 1, exiters: 1, EP: 0.0007007132546368883, C_mean: 0.13480973039868493, EP_fact: 0.0036466260891952944
# epoch45, number of firms: 18, entrats: 1, exiters: 2, EP: 0.0008320727511644688, C_mean: 0.13077296096713903, EP_fact: 0.004795919052955894
# epoch46, number of firms: 20, entrats: 2, exiters: 0, EP: 0.001670413687831442, C_mean: 0.1427963170581018, EP_fact: 0.0033860675984865142
# epoch47, number of firms: 20, entrats: 2, exiters: 2, EP: 0.0007965869107694774, C_mean: 0.13932093747849394, EP_fact: 0.002194646108560275
# epoch48, number of firms: 22, entrats: 2, exiters: 0, EP: 0.0011451045510266645, C_mean: 0.14782762034418578, EP_fact: 0.0014883367017911426
# epoch49, number of firms: 22, entrats: 2, exiters: 2, EP: 0.00046237668653584425, C_mean: 0.14507235494378487, EP_fact: 0.00034870943524454033
# epoch50, number of firms: 23, entrats: 1, exiters: 0, EP: 0.0004523904640488397, C_mean: 0.14812898750457715, EP_fact: 0.0005871699919071543
# epoch51, number of firms: 23, entrats: 1, exiters: 1, EP: 0.000555946593907385, C_mean: 0.1485523185264773, EP_fact: 0.0002025042231890671
# epoch52, number of firms: 21, entrats: 1, exiters: 3, EP: 0.0007337730262216447, C_mean: 0.1427918241253394, EP_fact: 0.0009172187744044097
# epoch53, number of firms: 22, entrats: 1, exiters: 0, EP: 0.002095623637150811, C_mean: 0.1515032865009667, EP_fact: 0.0015663589838695285
# epoch54, number of firms: 20, entrats: 3, exiters: 5, EP: 0.0005369501379910175, C_mean: 0.1382565457836447, EP_fact: 0.0008781000954325501
# epoch55, number of firms: 19, entrats: 1, exiters: 2, EP: 0.0006291965590908711, C_mean: 0.13451511933863128, EP_fact: 0.0032722827789555204
# epoch56, number of firms: 20, entrats: 1, exiters: 0, EP: 0.00131915032388011, C_mean: 0.14141827407508065, EP_fact: 0.003322914098023795
# epoch57, number of firms: 22, entrats: 2, exiters: 0, EP: 0.0023286864667552854, C_mean: 0.15237865288093555, EP_fact: 0.0015992465935708348
# epoch58, number of firms: 25, entrats: 3, exiters: 0, EP: 0.0008433736578981211, C_mean: 0.15515637714708258, EP_fact: -0.0007745601349952941
# epoch59, number of firms: 21, entrats: 1, exiters: 5, EP: 0.0004911864321782856, C_mean: 0.14179863852100402, EP_fact: -4.703086025433664e-05
# epoch60, number of firms: 21, entrats: 1, exiters: 1, EP: 0.0005072237649656215, C_mean: 0.14186471592401093, EP_fact: 0.001396737873038883
# epoch61, number of firms: 22, entrats: 1, exiters: 0, EP: 0.0005366982544303418, C_mean: 0.14537736099253423, EP_fact: 0.0011997973383892852
# epoch62, number of firms: 23, entrats: 1, exiters: 0, EP: 0.0009556285871312482, C_mean: 0.15016350968171507, EP_fact: 0.0009473473129651125
# epoch63, number of firms: 20, entrats: 2, exiters: 5, EP: 0.00042002141056762983, C_mean: 0.1377721074317633, EP_fact: 0.0006214756809155253
# epoch64, number of firms: 19, entrats: 1, exiters: 2, EP: 0.0004936512631367063, C_mean: 0.13395350103649897, EP_fact: 0.003091576374768478
# epoch65, number of firms: 19, entrats: 1, exiters: 1, EP: 0.0005080250548834004, C_mean: 0.13401326084150153, EP_fact: 0.0037153028814127104
# epoch66, number of firms: 20, entrats: 1, exiters: 0, EP: 0.0023807260520001, C_mean: 0.1455109056471652, EP_fact: 0.0032832048085643883
# epoch67, number of firms: 23, entrats: 3, exiters: 0, EP: 0.0006843607017338067, C_mean: 0.14907385730620795, EP_fact: 3.614481588844123e-05
# epoch68, number of firms: 22, entrats: 1, exiters: 2, EP: 0.0006640180440861832, C_mean: 0.1458969102892004, EP_fact: -8.59106430237709e-05
# epoch69, number of firms: 20, entrats: 1, exiters: 3, EP: 0.0006746337619713012, C_mean: 0.13882289680484847, EP_fact: 0.0015625327806190448
# epoch70, number of firms: 21, entrats: 1, exiters: 0, EP: 0.0015718884404771361, C_mean: 0.1461247685943649, EP_fact: 0.001903717628214516
# epoch71, number of firms: 21, entrats: 2, exiters: 2, EP: 0.0002406065335964925, C_mean: 0.14075828573052224, EP_fact: 0.0006878084502822888
# epoch72, number of firms: 20, entrats: 1, exiters: 2, EP: 0.0002860225838733788, C_mean: 0.13721295126159902, EP_fact: 0.001940912884480043
# epoch73, number of firms: 21, entrats: 1, exiters: 0, EP: 0.0005371661129466177, C_mean: 0.14198792489182543, EP_fact: 0.0019970819911669805
# epoch74, number of firms: 20, entrats: 1, exiters: 2, EP: 0.0005375482496334117, C_mean: 0.13825901553866865, EP_fact: 0.001920687714451265
# epoch75, number of firms: 19, entrats: 1, exiters: 2, EP: 0.0004305198926125315, C_mean: 0.13369045100837604, EP_fact: 0.003063480796440494
# epoch76, number of firms: 18, entrats: 1, exiters: 2, EP: 0.00040282574549231794, C_mean: 0.12899049811969565, EP_fact: 0.004452470597485613
# epoch77, number of firms: 19, entrats: 1, exiters: 0, EP: 0.002053461844834308, C_mean: 0.14017736111574533, EP_fact: 0.004652053856772796
# epoch78, number of firms: 18, entrats: 3, exiters: 4, EP: 0.00048640252787479805, C_mean: 0.12934092941655517, EP_fact: 0.0033703722700990204
# epoch79, number of firms: 17, entrats: 1, exiters: 2, EP: 0.0009767873833666663, C_mean: 0.12625482659553686, EP_fact: 0.006188752994036257
# epoch80, number of firms: 16, entrats: 2, exiters: 3, EP: 0.001015799747853612, C_mean: 0.12066715203996194, EP_fact: 0.0071073187886539595
# epoch81, number of firms: 17, entrats: 2, exiters: 1, EP: 0.0006311123016686394, C_mean: 0.12482580548512512, EP_fact: 0.006803444444577535
# epoch82, number of firms: 18, entrats: 1, exiters: 0, EP: 0.0005514149516283335, C_mean: 0.12961237510366527, EP_fact: 0.005982191906012805
# epoch83, number of firms: 17, entrats: 1, exiters: 2, EP: 0.0006625117242953244, C_mean: 0.12495673568515579, EP_fact: 0.0059119102268991265
# epoch84, number of firms: 18, entrats: 1, exiters: 0, EP: 0.000800451666435319, C_mean: 0.13064309705709964, EP_fact: 0.006213727235079304
# epoch85, number of firms: 19, entrats: 1, exiters: 0, EP: 0.0016277730172213224, C_mean: 0.13852809058101076, EP_fact: 0.004577826544144732
# epoch86, number of firms: 21, entrats: 2, exiters: 0, EP: 0.0009154210580095846, C_mean: 0.14352684710207578, EP_fact: 0.0024901334671970166
# epoch87, number of firms: 19, entrats: 1, exiters: 3, EP: 0.0004607842408072844, C_mean: 0.13381667154525434, EP_fact: 0.0029006772509371508
# epoch88, number of firms: 19, entrats: 1, exiters: 1, EP: 0.00030754083226007707, C_mean: 0.13317529832516986, EP_fact: 0.0039013700382024125
# epoch89, number of firms: 18, entrats: 1, exiters: 2, EP: 0.0007702916327764087, C_mean: 0.1305190238852584, EP_fact: 0.004706669846662727
# epoch90, number of firms: 18, entrats: 2, exiters: 2, EP: 0.0004595293162154169, C_mean: 0.1292284338320871, EP_fact: 0.004539878426205053
# epoch91, number of firms: 19, entrats: 1, exiters: 0, EP: 0.0006825735037071529, C_mean: 0.13473511490277126, EP_fact: 0.004778053773574745
# epoch92, number of firms: 20, entrats: 1, exiters: 0, EP: 0.0008802042318191861, C_mean: 0.13966049977677136, EP_fact: 0.00402550308904527
# epoch93, number of firms: 21, entrats: 1, exiters: 0, EP: 0.001246731620522969, C_mean: 0.14484911390084815, EP_fact: 0.003245218367440477
# epoch94, number of firms: 20, entrats: 2, exiters: 3, EP: 0.0003976173583969556, C_mean: 0.13767891832228124, EP_fact: 0.0020510363767945274
# epoch95, number of firms: 21, entrats: 1, exiters: 0, EP: 0.000734590972314238, C_mean: 0.14279515029257087, EP_fact: 0.0028234499224293113
# epoch96, number of firms: 22, entrats: 1, exiters: 0, EP: 0.000506009541678511, C_mean: 0.14525157398370905, EP_fact: 0.0018359782924372127
# epoch97, number of firms: 20, entrats: 1, exiters: 3, EP: 0.0007889721735200878, C_mean: 0.13928993762042294, EP_fact: 0.0021404007012215055
# epoch98, number of firms: 20, entrats: 2, exiters: 2, EP: 0.00046581848937599264, C_mean: 0.13796222894579874, EP_fact: 0.002573204969995067
# epoch99, number of firms: 18, entrats: 1, exiters: 3, EP: 0.0007561114925754443, C_mean: 0.13046061820858862, EP_fact: 0.004042270005396057
# epoch100, number of firms: 17, entrats: 2, exiters: 3, EP: 0.00021004010559630588, C_mean: 0.12304733512322583, EP_fact: 0.005446590466297471
# epoch101, number of firms: 17, entrats: 1, exiters: 1, EP: 0.0006607578520968233, C_mean: 0.12494942837037172, EP_fact: 0.006843446961259531
# epoch102, number of firms: 18, entrats: 1, exiters: 0, EP: 0.0008421505160451943, C_mean: 0.13081430201980032, EP_fact: 0.00613455683174131
# epoch103, number of firms: 19, entrats: 1, exiters: 0, EP: 0.0005340720937400002, C_mean: 0.13412142915304096, EP_fact: 0.004898058199116398
# epoch104, number of firms: 19, entrats: 1, exiters: 1, EP: 0.0004991570105683952, C_mean: 0.13397639721988383, EP_fact: 0.003995443602046233
# epoch105, number of firms: 19, entrats: 1, exiters: 1, EP: 0.0007109079895450555, C_mean: 0.13485163222993157, EP_fact: 0.004007581148240548
# epoch106, number of firms: 20, entrats: 1, exiters: 0, EP: 0.0005889371822527956, C_mean: 0.13847090350560304, EP_fact: 0.0033497069976595696
# epoch107, number of firms: 21, entrats: 1, exiters: 0, EP: 0.0007897561606992082, C_mean: 0.14301913362345495, EP_fact: 0.0023424770956614635
# epoch108, number of firms: 22, entrats: 1, exiters: 0, EP: 0.0009446548986573201, C_mean: 0.1470292672225615, EP_fact: 0.001587851329596483
# epoch109, number of firms: 17, entrats: 2, exiters: 7, EP: 0.000670165646737832, C_mean: 0.12498861657332257, EP_fact: 0.0030275744825336644
# epoch110, number of firms: 18, entrats: 1, exiters: 0, EP: 0.00042988584534060965, C_mean: 0.12910414190999886, EP_fact: 0.005845046306015757
# epoch111, number of firms: 19, entrats: 1, exiters: 0, EP: 0.001311265990213058, C_mean: 0.13727886184777777, EP_fact: 0.004750262408880379
# epoch112, number of firms: 21, entrats: 2, exiters: 0, EP: 0.0004829824673339856, C_mean: 0.14176481313416062, EP_fact: 0.002993386642112214
# epoch113, number of firms: 20, entrats: 1, exiters: 2, EP: 0.0004748042978878226, C_mean: 0.13799947442885332, EP_fact: 0.0024065246923185815
# epoch114, number of firms: 19, entrats: 1, exiters: 2, EP: 0.0003112212512431812, C_mean: 0.13319076841674415, EP_fact: 0.00320385796627451
# epoch115, number of firms: 19, entrats: 1, exiters: 1, EP: 0.0005495435103767144, C_mean: 0.13418560375580255, EP_fact: 0.0037255216713508463
# epoch116, number of firms: 20, entrats: 1, exiters: 0, EP: 0.001161169924931581, C_mean: 0.14079033230729557, EP_fact: 0.003411466064190769
# epoch117, number of firms: 22, entrats: 2, exiters: 0, EP: 0.0009429154335986473, C_mean: 0.14702230171568678, EP_fact: 0.0015442842685374006
# epoch118, number of firms: 20, entrats: 2, exiters: 4, EP: 0.00027664301408518617, C_mean: 0.13717364955569455, EP_fact: 0.0010338461501474584
# epoch119, number of firms: 21, entrats: 1, exiters: 0, EP: 0.0005076545631643187, C_mean: 0.1418664900821139, EP_fact: 0.0024110297699204337
# epoch120, number of firms: 19, entrats: 1, exiters: 3, EP: 0.0007220418634688048, C_mean: 0.1348973670875221, EP_fact: 0.0025759952086509825
# epoch121, number of firms: 19, entrats: 1, exiters: 1, EP: 0.0008398027302916767, C_mean: 0.13537938519935966, EP_fact: 0.0036559274185348593
# epoch122, number of firms: 18, entrats: 2, exiters: 3, EP: 0.0008249953894995127, C_mean: 0.13074391459525003, EP_fact: 0.003918063991593586
# epoch123, number of firms: 18, entrats: 2, exiters: 2, EP: 0.0008566055093854903, C_mean: 0.1308735597428992, EP_fact: 0.004544450815855359
# epoch124, number of firms: 17, entrats: 2, exiters: 3, EP: 0.0005208600015408089, C_mean: 0.1243642465563856, EP_fact: 0.00546902642229733
# epoch125, number of firms: 18, entrats: 1, exiters: 0, EP: 0.0006000757260011414, C_mean: 0.12981489864870596, EP_fact: 0.006308991629316586
# epoch126, number of firms: 16, entrats: 1, exiters: 3, EP: 0.0005570814702143007, C_mean: 0.1187564371762184, EP_fact: 0.0068236014748791676
# epoch127, number of firms: 17, entrats: 1, exiters: 0, EP: 0.0020500588517245195, C_mean: 0.1305302988264414, EP_fact: 0.007731142348859514
# epoch128, number of firms: 18, entrats: 3, exiters: 2, EP: 0.00047912731042762564, C_mean: 0.12931049112491325, EP_fact: 0.004676318773607144
# epoch129, number of firms: 17, entrats: 1, exiters: 2, EP: 0.00017159653768791978, C_mean: 0.12288280021035757, EP_fact: 0.00589575905438653
# epoch130, number of firms: 18, entrats: 1, exiters: 0, EP: 0.0003967184976376454, C_mean: 0.12896482529252695, EP_fact: 0.0060448758233003375
# epoch131, number of firms: 19, entrats: 1, exiters: 0, EP: 0.0009488436498104481, C_mean: 0.13582295951405263, EP_fact: 0.004965982865470812
# epoch132, number of firms: 18, entrats: 1, exiters: 2, EP: 0.0006051751060159195, C_mean: 0.1298360900317389, EP_fact: 0.0046739060548377075
# epoch133, number of firms: 19, entrats: 1, exiters: 0, EP: 0.0037628744719649127, C_mean: 0.14648214128418455, EP_fact: 0.0044556419064315025
# epoch134, number of firms: 21, entrats: 4, exiters: 2, EP: 0.0007175509388350505, C_mean: 0.1427258261959394, EP_fact: 0.0011198384202517565
# epoch135, number of firms: 22, entrats: 1, exiters: 0, EP: 0.0007046281999730248, C_mean: 0.14606185244108943, EP_fact: 0.001442177501567915
# epoch136, number of firms: 20, entrats: 1, exiters: 3, EP: 0.0006043596411809838, C_mean: 0.13853437461202184, EP_fact: 0.0015945403653205071
# epoch137, number of firms: 18, entrats: 1, exiters: 3, EP: 0.0007680381680820903, C_mean: 0.13050974527453849, EP_fact: 0.004327576709420618
# epoch138, number of firms: 19, entrats: 2, exiters: 1, EP: 0.0005632122642691018, C_mean: 0.13424225452744498, EP_fact: 0.003967702442786418
# epoch139, number of firms: 20, entrats: 1, exiters: 0, EP: 0.0016065313347882904, C_mean: 0.14254752171548488, EP_fact: 0.0036078362921434077
# epoch140, number of firms: 22, entrats: 2, exiters: 0, EP: 0.0007558649301348825, C_mean: 0.14626942766897055, EP_fact: 0.0020136316835562247
# epoch141, number of firms: 19, entrats: 1, exiters: 4, EP: 0.00023048138249801182, C_mean: 0.13285063047965182, EP_fact: 0.0023200331035928717
# epoch142, number of firms: 19, entrats: 1, exiters: 1, EP: 0.0005808500421653501, C_mean: 0.1343152908290356, EP_fact: 0.003766315427409646
# epoch143, number of firms: 20, entrats: 1, exiters: 0, EP: 0.0011895534172724504, C_mean: 0.14090353406868827, EP_fact: 0.003575667676010996
# epoch144, number of firms: 19, entrats: 2, exiters: 3, EP: 0.00037555118402951733, C_mean: 0.13346063975566844, EP_fact: 0.002773513421603131
# epoch145, number of firms: 17, entrats: 1, exiters: 3, EP: 0.0008070176064984159, C_mean: 0.12555637563043262, EP_fact: 0.005695530470913661
# epoch146, number of firms: 19, entrats: 2, exiters: 0, EP: 0.0016296916930665668, C_mean: 0.1385356024431395, EP_fact: 0.00517459716026319
# epoch147, number of firms: 21, entrats: 2, exiters: 0, EP: 0.0010268994641708818, C_mean: 0.1439743644509421, EP_fact: 0.002646806490412678
# epoch148, number of firms: 22, entrats: 2, exiters: 1, EP: 0.0005617733989393154, C_mean: 0.14547997763984719, EP_fact: 0.00104392685013538
# epoch149, number of firms: 20, entrats: 1, exiters: 3, EP: 0.0003088008877084065, C_mean: 0.13730830660256296, EP_fact: 0.0017555507115936458
# epoch150, number of firms: 18, entrats: 1, exiters: 3, EP: 0.0002287683751400916, C_mean: 0.12825526647790714, EP_fact: 0.004268430661849245
# epoch151, number of firms: 18, entrats: 1, exiters: 1, EP: 0.0008644105034157929, C_mean: 0.13090553665916493, EP_fact: 0.0050533998386941194
# epoch152, number of firms: 20, entrats: 2, exiters: 0, EP: 0.0007992822329827304, C_mean: 0.13933190713025748, EP_fact: 0.0032082393734369453
# epoch153, number of firms: 21, entrats: 1, exiters: 0, EP: 0.002131818760404582, C_mean: 0.14827336111344872, EP_fact: 0.0025878315365459896
# epoch154, number of firms: 24, entrats: 3, exiters: 0, EP: 0.0013196138552520349, C_mean: 0.15442889515975794, EP_fact: 0.00022871837920057937
# epoch155, number of firms: 21, entrats: 2, exiters: 5, EP: 0.00046445610333717587, C_mean: 0.14168836999645792, EP_fact: 0.00016347245852560367
# epoch156, number of firms: 17, entrats: 1, exiters: 5, EP: 0.0007572929221622161, C_mean: 0.12535057715713474, EP_fact: 0.004120773660444642
# epoch157, number of firms: 17, entrats: 2, exiters: 2, EP: 0.000588496348100433, C_mean: 0.12464773692499669, EP_fact: 0.006233706404982875
# epoch158, number of firms: 18, entrats: 1, exiters: 0, EP: 0.0021074391136939197, C_mean: 0.13583582251822254, EP_fact: 0.006394685081654796
# epoch159, number of firms: 19, entrats: 2, exiters: 1, EP: 0.000529561986481188, C_mean: 0.13410271093418427, EP_fact: 0.004019405694411856
# epoch160, number of firms: 17, entrats: 1, exiters: 3, EP: 0.0002573101078486035, C_mean: 0.12324913975269496, EP_fact: 0.005463639449663749
# epoch161, number of firms: 18, entrats: 1, exiters: 0, EP: 0.0015222443627288407, C_mean: 0.13355356793946738, EP_fact: 0.0057226467160444916
# epoch162, number of firms: 20, entrats: 2, exiters: 0, EP: 0.0015407099172274914, C_mean: 0.14229033682543574, EP_fact: 0.0032180303595752526
# epoch163, number of firms: 20, entrats: 2, exiters: 2, EP: 0.0005317888142448591, C_mean: 0.13823522990531825, EP_fact: 0.001987130835612123
# epoch164, number of firms: 18, entrats: 1, exiters: 3, EP: 0.0007365898179086828, C_mean: 0.13038013704181478, EP_fact: 0.0038467103556780505
# epoch165, number of firms: 19, entrats: 1, exiters: 0, EP: 0.0009271627424968249, C_mean: 0.13573497078296168, EP_fact: 0.004681582794243893
# epoch166, number of firms: 20, entrats: 1, exiters: 0, EP: 0.0021049021047022404, C_mean: 0.1444678075701823, EP_fact: 0.003373950353455394
# epoch167, number of firms: 21, entrats: 3, exiters: 2, EP: 0.0006394824551613516, C_mean: 0.14240738200382405, EP_fact: 0.0013517347244748107
# epoch168, number of firms: 22, entrats: 1, exiters: 0, EP: 0.001753824781227169, C_mean: 0.1502016291484718, EP_fact: 0.0017053044542006076
# epoch169, number of firms: 24, entrats: 2, exiters: 0, EP: 0.0005644777455504919, C_mean: 0.151425126194758, EP_fact: 0.0001340286901051523
# epoch170, number of firms: 22, entrats: 1, exiters: 3, EP: 0.00045305129555838104, C_mean: 0.1450339939081946, EP_fact: -0.00011569397018123554
# epoch171, number of firms: 21, entrats: 1, exiters: 2, EP: 0.0005033644011037831, C_mean: 0.14184881996029583, EP_fact: 0.001137187597475532
# epoch172, number of firms: 22, entrats: 1, exiters: 0, EP: 0.0016529788849376382, C_mean: 0.14981338319732387, EP_fact: 0.0012462653739314618
# epoch173, number of firms: 20, entrats: 2, exiters: 4, EP: 0.0004968290635917628, C_mean: 0.1380906851119874, EP_fact: 0.0012586620757134661
# epoch174, number of firms: 20, entrats: 1, exiters: 1, EP: 0.000353798984292707, C_mean: 0.1374963106107046, EP_fact: 0.0026367641031298243
# epoch175, number of firms: 20, entrats: 1, exiters: 1, EP: 0.0003462766611523494, C_mean: 0.13746491597086033, EP_fact: 0.002518673011759283
# epoch176, number of firms: 20, entrats: 1, exiters: 1, EP: 0.000764479492326527, C_mean: 0.13919013923375687, EP_fact: 0.0023544168402356304
# epoch177, number of firms: 19, entrats: 2, exiters: 3, EP: 0.00032238663048597856, C_mean: 0.13323768028208366, EP_fact: 0.002985492904617457
# epoch178, number of firms: 20, entrats: 1, exiters: 0, EP: 0.0006481516783454506, C_mean: 0.13871430276456304, EP_fact: 0.003230676635126284
# epoch179, number of firms: 19, entrats: 1, exiters: 2, EP: 0.0005114463502366041, C_mean: 0.13402747790038333, EP_fact: 0.0031532440516818133
# epoch180, number of firms: 19, entrats: 1, exiters: 1, EP: 0.0006734033765303116, C_mean: 0.13469736621803188, EP_fact: 0.003447167510539672
# epoch181, number of firms: 19, entrats: 2, exiters: 2, EP: 0.00037470762784024177, C_mean: 0.13345710740372518, EP_fact: 0.0028292274192487587
# epoch182, number of firms: 19, entrats: 1, exiters: 1, EP: 0.0002736145714072758, C_mean: 0.1330325389056223, EP_fact: 0.0034545584776283734
# epoch183, number of firms: 18, entrats: 1, exiters: 2, EP: 0.000743961773403511, C_mean: 0.130410539253406, EP_fact: 0.004707897645078436
# epoch184, number of firms: 20, entrats: 2, exiters: 0, EP: 0.000455428132754428, C_mean: 0.13791913800219463, EP_fact: 0.003132567794001592
# epoch185, number of firms: 18, entrats: 1, exiters: 3, EP: 0.0006033479737196524, C_mean: 0.12982849775273322, EP_fact: 0.003670331134641703
# epoch186, number of firms: 19, entrats: 1, exiters: 0, EP: 0.00029067732171196743, C_mean: 0.13310437290850324, EP_fact: 0.00431822335675795
# epoch187, number of firms: 19, entrats: 1, exiters: 1, EP: 0.0003325766497011013, C_mean: 0.1332804677258849, EP_fact: 0.003983696234882633
# epoch188, number of firms: 18, entrats: 1, exiters: 2, EP: 0.0004969088392474553, C_mean: 0.12938486391746581, EP_fact: 0.004421298536533365
# epoch189, number of firms: 19, entrats: 1, exiters: 0, EP: 0.0016785013208939093, C_mean: 0.1387264557326913, EP_fact: 0.004595239177003477
# epoch190, number of firms: 19, entrats: 2, exiters: 2, EP: 0.0007441166640920361, C_mean: 0.13498796117000794, EP_fact: 0.0032705123369492495
# epoch191, number of firms: 20, entrats: 1, exiters: 0, EP: 0.0005441658927808225, C_mean: 0.13828633591467826, EP_fact: 0.0033658182148200225
# epoch192, number of firms: 20, entrats: 1, exiters: 1, EP: 0.0004438793493392063, C_mean: 0.13787121292401344, EP_fact: 0.0027654066807004485
# epoch193, number of firms: 20, entrats: 1, exiters: 1, EP: 0.0005247858079710527, C_mean: 0.13820629809305449, EP_fact: 0.0027300429557996124
# epoch194, number of firms: 21, entrats: 1, exiters: 0, EP: 0.0014415842351764453, C_mean: 0.14561611130461624, EP_fact: 0.0027275411007070052
# epoch195, number of firms: 20, entrats: 2, exiters: 3, EP: 0.000695681199800265, C_mean: 0.13890909140657756, EP_fact: 0.0017288910950694388
# epoch196, number of firms: 20, entrats: 1, exiters: 1, EP: 0.0005991855216396936, C_mean: 0.13851308663944603, EP_fact: 0.002582569701707046
# epoch197, number of firms: 19, entrats: 1, exiters: 2, EP: 0.0007434697526545204, C_mean: 0.13498530783959486, EP_fact: 0.0032049333117698986
# epoch198, number of firms: 20, entrats: 1, exiters: 0, EP: 0.0025909408860547867, C_mean: 0.14629689971167303, EP_fact: 0.0034319348381186263
# epoch199, number of firms: 23, entrats: 3, exiters: 0, EP: 0.0010437402571674432, C_mean: 0.1505140119037598, EP_fact: 0.000823435515732096

# %%
result = Noke.getData()
result
# Out:
#      param_0  param_1  sigma   S     f    ef     r  alpha   NPV_ent  n_firms  \
# 0        0.1      0.2    0.5  16  0.01  0.01  0.01    0.8 -0.032089       15
# 1        0.1      0.2    0.5  16  0.01  0.01  0.01    0.8 -0.074966       21
# 2        0.1      0.2    0.5  16  0.01  0.01  0.01    0.8 -0.073130       23
# 3        0.1      0.2    0.5  16  0.01  0.01  0.01    0.8 -0.044191       24
# 4        0.1      0.2    0.5  16  0.01  0.01  0.01    0.8 -0.032370       21
# ..       ...      ...    ...  ..   ...   ...   ...    ...       ...      ...
# 195      0.1      0.2    0.5  16  0.01  0.01  0.01    0.8 -0.028983       20
# 196      0.1      0.2    0.5  16  0.01  0.01  0.01    0.8  0.003783       20
# 197      0.1      0.2    0.5  16  0.01  0.01  0.01    0.8 -0.007873       19
# 198      0.1      0.2    0.5  16  0.01  0.01  0.01    0.8  0.005266       20
# 199      0.1      0.2    0.5  16  0.01  0.01  0.01    0.8 -0.025711       23
#
#       Pr_mean        EP    C_mean     C_max    Sigma2  n_entr  n_ext
# 0    0.010934  0.014166  0.156872  0.194583  0.256064       5      0
# 1    0.002674  0.003151  0.152041  0.199401  0.225777       6      0
# 2    0.000296  0.000527  0.148433  0.194583  0.216559       3      1
# 3   -0.000254  0.000545  0.151346  0.194583  0.216627       1      0
# 4    0.000492  0.000528  0.141952  0.173111  0.216564       1      4
# ..        ...       ...       ...       ...       ...     ...    ...
# 195  0.001729  0.000696  0.138909  0.170732  0.217190       2      3
# 196  0.002583  0.000599  0.138513  0.173644  0.216830       1      1
# 197  0.003205  0.000743  0.134985  0.170732  0.217368       1      2
# 198  0.003432  0.002591  0.146297  0.199300  0.223906       1      0
# 199  0.000823  0.001044  0.150514  0.199300  0.218473       3      0
#
# [200 rows x 17 columns]

# %%
np.mean(result['C_mean'])
# Out:
# 0.13787239903719223

# %%
result.to_csv("results.csv")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 result.to_csv("results.csv")
#
# File c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:3961, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3950 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3952 formatter = DataFrameFormatter(
#    3953     frame=df,
#    3954     header=header,
#    (...)
#    3958     decimal=decimal,
#    3959 )
# -> 3961 return DataFrameRenderer(formatter).to_csv(
#    3962     path_or_buf,
#    3963     lineterminator=lineterminator,
#    3964     sep=sep,
#    3965     encoding=encoding,
#    3966     errors=errors,
#    3967     compression=compression,
#    3968     quoting=quoting,
#    3969     columns=columns,
#    3970     index_label=index_label,
#    3971     mode=mode,
#    3972     chunksize=chunksize,
#    3973     quotechar=quotechar,
#    3974     date_format=date_format,
#    3975     doublequote=doublequote,
#    3976     escapechar=escapechar,
#    3977     storage_options=storage_options,
#    3978 )
#
# File c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: 'results.csv'

# %%
plt.figure(figsize=(10,5))
plt.subplot(2,1,1)
plt.title('n_firms')
plt.plot(result["n_firms"])
plt.subplot(2,1,2)
plt.title('Mean C')
plt.plot(result["C_mean"])

# %%
#ШОК СТАВОЧКИ

for i in range(100, 200):
    df["r"][i] = 0.2

Noke.setData(df)
Noke.scenario(out = True)
# Out:
# epoch0, number of firms: 61, entrats: 51, exiters: 0, EP: 0.00018975874526580973, C_mean: 0.39334321329612737, EP_fact: 0.00025463427204193607
# epoch1, number of firms: 61, entrats: 0, exiters: 0, EP: 0.00034153738020542643, C_mean: 0.39809191376277075, EP_fact: 0.00036010954529708017
# epoch2, number of firms: 94, entrats: 33, exiters: 0, EP: 0.00018264391645274238, C_mean: 0.3998746424856626, EP_fact: 0.0003472013464105985
# epoch3, number of firms: 14, entrats: 0, exiters: 80, EP: -0.00011315873236499344, C_mean: 0.31668122867635795, EP_fact: 0.00010922546285739392
# epoch4, number of firms: 14, entrats: 0, exiters: 0, EP: 0.00041125262029665364, C_mean: 0.3362241006648042, EP_fact: 0.003643085204422762
# epoch5, number of firms: 16, entrats: 2, exiters: 0, EP: 0.0005040644536548307, C_mean: 0.3494730375680753, EP_fact: 0.00266100046529401
# epoch6, number of firms: 30, entrats: 14, exiters: 0, EP: 0.00029367314162736906, C_mean: 0.3768419695290434, EP_fact: 0.0008976946951697729
# epoch7, number of firms: 32, entrats: 2, exiters: 0, EP: 0.0005523705363402215, C_mean: 0.38698377982470167, EP_fact: 0.0010152694836192138
# epoch8, number of firms: 14, entrats: 13, exiters: 31, EP: -6.1423452762830386e-06, C_mean: 0.3211975269247906, EP_fact: 0.0003687408433760814
# epoch9, number of firms: 14, entrats: 0, exiters: 0, EP: 2.901646242180569e-05, C_mean: 0.3226101630341812, EP_fact: 0.0027361639408036336
# epoch10, number of firms: 14, entrats: 0, exiters: 0, EP: 2.901646242180569e-05, C_mean: 0.3226101630341812, EP_fact: 0.0027361639408036336
# epoch11, number of firms: 14, entrats: 0, exiters: 0, EP: 0.00039540670648660907, C_mean: 0.33571232712991267, EP_fact: 0.0033125020647810054
# epoch12, number of firms: 17, entrats: 3, exiters: 0, EP: 0.0002880496127925481, C_mean: 0.34687089378062513, EP_fact: 0.002583518980488761
# epoch13, number of firms: 19, entrats: 2, exiters: 0, EP: 0.0005030008647498357, C_mean: 0.36085406372925943, EP_fact: 0.0025352698358019495
# epoch14, number of firms: 22, entrats: 3, exiters: 0, EP: 0.0003962768152236721, C_mean: 0.36593414148011194, EP_fact: 0.001944017300460926
# epoch15, number of firms: 30, entrats: 8, exiters: 0, EP: 0.0003192428134977611, C_mean: 0.37765038964408293, EP_fact: 0.0011326816364840954
# epoch16, number of firms: 18, entrats: 19, exiters: 31, EP: -0.00031492112156506305, C_mean: 0.32630960740324366, EP_fact: 0.00045310324422861005
# epoch17, number of firms: 15, entrats: 0, exiters: 3, EP: -6.807271409522411e-06, C_mean: 0.32682740497219676, EP_fact: 0.0016946799560630882
# epoch18, number of firms: 15, entrats: 0, exiters: 0, EP: 0.0005778473958244802, C_mean: 0.34687475785290517, EP_fact: 0.0028893888925729814
# epoch19, number of firms: 19, entrats: 4, exiters: 0, EP: 0.00025094829324964524, C_mean: 0.3528688236623934, EP_fact: 0.0015777615728722824
# epoch20, number of firms: 20, entrats: 1, exiters: 0, EP: 0.0008329375478402683, C_mean: 0.37305476330817633, EP_fact: 0.0016549054167805863
# epoch21, number of firms: 38, entrats: 18, exiters: 0, EP: 0.00012396782935017556, C_mean: 0.37946014124168365, EP_fact: 0.0006135027699654877
# epoch22, number of firms: 16, entrats: 0, exiters: 22, EP: -0.0001731198001691071, C_mean: 0.3247088561781426, EP_fact: 0.0005508490351256229
# epoch23, number of firms: 14, entrats: 0, exiters: 2, EP: 5.9163396630736815e-05, C_mean: 0.3237960203034224, EP_fact: 0.0022098994506650725
# epoch24, number of firms: 14, entrats: 0, exiters: 0, EP: 0.0005221859079401567, C_mean: 0.33970381353415735, EP_fact: 0.003420995467394336
# epoch25, number of firms: 16, entrats: 2, exiters: 0, EP: 0.00019063801411735954, C_mean: 0.33920862727608314, EP_fact: 0.0025413322902865117
# epoch26, number of firms: 16, entrats: 0, exiters: 0, EP: 0.00022599254875804134, C_mean: 0.3404505669784319, EP_fact: 0.0025386774287318014
# epoch27, number of firms: 17, entrats: 1, exiters: 0, EP: 0.00029979239985772257, C_mean: 0.3472624055658351, EP_fact: 0.002394035360859829
# epoch28, number of firms: 23, entrats: 6, exiters: 0, EP: 0.0008990040038764494, C_mean: 0.3821672663644448, EP_fact: 0.0024291331333752145
# epoch29, number of firms: 58, entrats: 35, exiters: 0, EP: 0.0003628361317485633, C_mean: 0.3977418181677255, EP_fact: 0.00034070273611899065
# epoch30, number of firms: 96, entrats: 38, exiters: 0, EP: 0.00029237313155740545, C_mean: 0.4035786843398362, EP_fact: 0.00012247027729131804
# epoch31, number of firms: 130, entrats: 34, exiters: 0, EP: 0.0001424502731806668, C_mean: 0.4020292965322075, EP_fact: -1.4650291775025587e-05
# epoch32, number of firms: 130, entrats: 0, exiters: 0, EP: 0.00020096413555041538, C_mean: 0.4039230899114754, EP_fact: -6.191717872158518e-05
# epoch33, number of firms: 134, entrats: 4, exiters: 0, EP: 0.00019662506479239277, C_mean: 0.40405445446198884, EP_fact: -8.436035034611747e-05
# epoch34, number of firms: 136, entrats: 2, exiters: 0, EP: 0.0002126577824210342, C_mean: 0.4046923358873967, EP_fact: -9.774820185755384e-05
# epoch35, number of firms: 138, entrats: 2, exiters: 0, EP: 0.00016293767521969498, C_mean: 0.40322421053237983, EP_fact: -0.00013350278798854962
# epoch36, number of firms: 138, entrats: 0, exiters: 0, EP: 0.00022041353382996312, C_mean: 0.40506194034702225, EP_fact: -2.4092436739617625e-05
# epoch37, number of firms: 151, entrats: 13, exiters: 0, EP: 0.00013987994401588985, C_mean: 0.4032048411100867, EP_fact: -6.681429741133506e-05
# epoch38, number of firms: 151, entrats: 0, exiters: 0, EP: 0.0002578096837396963, C_mean: 0.406957131295169, EP_fact: -5.0392284860776936e-05
# epoch39, number of firms: 157, entrats: 6, exiters: 0, EP: 0.0002190670553535658, C_mean: 0.40604818424032163, EP_fact: -0.00011593492976098807
# epoch40, number of firms: 23, entrats: 9, exiters: 143, EP: -0.000555113899248009, C_mean: 0.32730747841666824, EP_fact: -0.0003128702253738867
# epoch41, number of firms: 15, entrats: 0, exiters: 8, EP: -4.297457374339479e-05, C_mean: 0.32535077457621714, EP_fact: 0.001649788533614624
# epoch42, number of firms: 15, entrats: 0, exiters: 0, EP: 0.0002656382335136768, C_mean: 0.33693972422019364, EP_fact: 0.002801531316698929
# epoch43, number of firms: 16, entrats: 1, exiters: 0, EP: 0.0010238878403205343, C_mean: 0.36371971602752373, EP_fact: 0.0028136573632820427
# epoch44, number of firms: 15, entrats: 10, exiters: 11, EP: -2.481233851249747e-05, C_mean: 0.32609686226907597, EP_fact: 0.001109009678081489
# epoch45, number of firms: 15, entrats: 0, exiters: 0, EP: 0.0004322377423924843, C_mean: 0.3424218588939682, EP_fact: 0.0026784132239227234
# epoch46, number of firms: 32, entrats: 17, exiters: 0, EP: 0.00037677840634461825, C_mean: 0.38185609174573515, EP_fact: 0.0010844809948226384
# epoch47, number of firms: 36, entrats: 4, exiters: 0, EP: 0.0003911765098766711, C_mean: 0.38632973398003007, EP_fact: 0.000788138861980541
# epoch48, number of firms: 43, entrats: 7, exiters: 0, EP: 0.0002446566777709845, C_mean: 0.38706659803727445, EP_fact: 0.00038117508890678735
# epoch49, number of firms: 45, entrats: 2, exiters: 0, EP: 0.00018306584234323688, C_mean: 0.38627464400426836, EP_fact: 0.00043760298909529594
# epoch50, number of firms: 45, entrats: 0, exiters: 0, EP: 0.0002489513125736682, C_mean: 0.3884144879615883, EP_fact: 0.00037288838440066986
# epoch51, number of firms: 61, entrats: 16, exiters: 0, EP: 0.00021169493220482343, C_mean: 0.3940535892393282, EP_fact: 0.00033731400194991784
# epoch52, number of firms: 62, entrats: 1, exiters: 0, EP: 0.00016449178510615382, C_mean: 0.3928251212653062, EP_fact: 0.0003323698821820914
# epoch53, number of firms: 62, entrats: 0, exiters: 0, EP: 0.0005053169987666269, C_mean: 0.4031355866621715, EP_fact: 0.0002734523569767175
# epoch54, number of firms: 111, entrats: 49, exiters: 0, EP: 0.0001177339700229262, C_mean: 0.3996569498452976, EP_fact: 5.721938806729043e-05
# epoch55, number of firms: 17, entrats: 0, exiters: 94, EP: -0.00030821432144785327, C_mean: 0.32268727750635373, EP_fact: -0.00018647756780301652
# epoch56, number of firms: 15, entrats: 0, exiters: 2, EP: -0.00010108322629533584, C_mean: 0.32289836202271716, EP_fact: 0.0022798966000949217
# epoch57, number of firms: 15, entrats: 0, exiters: 0, EP: 0.00030133302435084836, C_mean: 0.338153084786334, EP_fact: 0.0029464453535135784
# epoch58, number of firms: 18, entrats: 3, exiters: 0, EP: 0.0011111472552043995, C_mean: 0.3736913349986292, EP_fact: 0.0028110096031604827
# epoch59, number of firms: 53, entrats: 35, exiters: 0, EP: 0.0003187889389617746, C_mean: 0.39451628335876954, EP_fact: 0.0006784983427281817
# epoch60, number of firms: 64, entrats: 11, exiters: 0, EP: 0.000234307557402268, C_mean: 0.39567758206793596, EP_fact: 0.0004777306010488831
# epoch61, number of firms: 77, entrats: 13, exiters: 0, EP: 0.0003699656305186333, C_mean: 0.40290587493890867, EP_fact: 0.0004470574925917177
# epoch62, number of firms: 20, entrats: 33, exiters: 90, EP: -0.0004954913090062794, C_mean: 0.3230556294631074, EP_fact: -9.84311818064641e-05
# epoch63, number of firms: 20, entrats: 0, exiters: 0, EP: 0.00034284873216760886, C_mean: 0.35896211043983806, EP_fact: 0.0022750905767360344
# epoch64, number of firms: 25, entrats: 5, exiters: 0, EP: 0.00045938769712023254, C_mean: 0.37417903996740853, EP_fact: 0.001738230182495791
# epoch65, number of firms: 28, entrats: 3, exiters: 0, EP: 0.00031923525908802335, C_mean: 0.3748718048162968, EP_fact: 0.0014307430714793437
# epoch66, number of firms: 15, entrats: 26, exiters: 39, EP: -0.00014407992170181933, C_mean: 0.32101481834880563, EP_fact: 0.00038204484697026167
# epoch67, number of firms: 15, entrats: 0, exiters: 0, EP: 0.0002896602733676041, C_mean: 0.3377587659894254, EP_fact: 0.0029660400834936223
# epoch68, number of firms: 21, entrats: 6, exiters: 0, EP: 0.00024301234136223288, C_mean: 0.35847274345957314, EP_fact: 0.0018770152291273598
# epoch69, number of firms: 22, entrats: 1, exiters: 0, EP: 0.0005664792850014681, C_mean: 0.3709983946457481, EP_fact: 0.0018023171171442627
# epoch70, number of firms: 34, entrats: 12, exiters: 0, EP: 0.0008205748963726238, C_mean: 0.39621302078614906, EP_fact: 0.001188398405512243
# epoch71, number of firms: 14, entrats: 24, exiters: 44, EP: -2.861432136003672e-05, C_mean: 0.32027709431412604, EP_fact: 0.000114483232116489
# epoch72, number of firms: 14, entrats: 0, exiters: 0, EP: 0.00015166331200104828, C_mean: 0.3272997467415705, EP_fact: 0.0027264197351500987
# epoch73, number of firms: 14, entrats: 0, exiters: 0, EP: 0.0003874203211887697, C_mean: 0.3354529224040025, EP_fact: 0.0031141825427173824
# epoch74, number of firms: 23, entrats: 9, exiters: 0, EP: 0.0007070611381274534, C_mean: 0.37717594297300766, EP_fact: 0.002058863402949744
# epoch75, number of firms: 37, entrats: 14, exiters: 0, EP: 0.0004991459268332231, C_mean: 0.39035721568589943, EP_fact: 0.0010093237745563088
# epoch76, number of firms: 14, entrats: 41, exiters: 64, EP: -6.615451049994236e-05, C_mean: 0.31870728462672276, EP_fact: 3.747372690263568e-05
# epoch77, number of firms: 14, entrats: 0, exiters: 0, EP: 0.0005017928521617741, C_mean: 0.33907712572690346, EP_fact: 0.003109127337525726
# epoch78, number of firms: 16, entrats: 2, exiters: 0, EP: 0.00044678153624361683, C_mean: 0.34771159119853373, EP_fact: 0.0025447818566726147
# epoch79, number of firms: 23, entrats: 7, exiters: 0, EP: 0.0006004657312227799, C_mean: 0.37424060709586965, EP_fact: 0.0019016786859489155
# epoch80, number of firms: 40, entrats: 17, exiters: 0, EP: 0.00028717417316544256, C_mean: 0.38637488184450053, EP_fact: 0.0008690014902154918
# epoch81, number of firms: 52, entrats: 12, exiters: 0, EP: 0.00025819512950404585, C_mean: 0.39221031254901095, EP_fact: 0.0006301187959615281
# epoch82, number of firms: 54, entrats: 2, exiters: 0, EP: 0.00010855636830048483, C_mean: 0.38812722192911575, EP_fact: 0.0005119029516520236
# epoch83, number of firms: 54, entrats: 0, exiters: 0, EP: 0.00013669263456949732, C_mean: 0.38908409906904884, EP_fact: 0.0004316045106894249
# epoch84, number of firms: 54, entrats: 0, exiters: 0, EP: 0.0002889779249877953, C_mean: 0.3940064698061735, EP_fact: 0.00047831052932967684
# epoch85, number of firms: 73, entrats: 19, exiters: 0, EP: 0.0005736798171877551, C_mean: 0.40781233314204796, EP_fact: 0.0004528969177372918
# epoch86, number of firms: 145, entrats: 72, exiters: 0, EP: 0.0002531406255197701, C_mean: 0.40649227892934675, EP_fact: 0.00011960365681682247
# epoch87, number of firms: 159, entrats: 14, exiters: 0, EP: 0.00013211719824250483, C_mean: 0.4033416163126035, EP_fact: 2.9484740065463455e-05
# epoch88, number of firms: 159, entrats: 0, exiters: 0, EP: 0.00017785599968493052, C_mean: 0.40483200518273443, EP_fact: 1.5122108382467164e-05
# epoch89, number of firms: 159, entrats: 0, exiters: 0, EP: 0.0002854643935139892, C_mean: 0.40819227163500893, EP_fact: 6.989392575162585e-05
# epoch90, number of firms: 174, entrats: 15, exiters: 0, EP: 0.0001533179662585554, C_mean: 0.40467554756376733, EP_fact: 0.00015232086260975867
# epoch91, number of firms: 174, entrats: 0, exiters: 0, EP: 0.00020344597350176186, C_mean: 0.40628555798010746, EP_fact: 7.115246676315277e-05
# epoch92, number of firms: 180, entrats: 6, exiters: 0, EP: 0.00015888143701426813, C_mean: 0.40508194184679586, EP_fact: 7.861609569852177e-05
# epoch93, number of firms: 19, entrats: 0, exiters: 161, EP: -0.0005086284742426679, C_mean: 0.3189979404785184, EP_fact: -0.0002810417128480131
# epoch94, number of firms: 13, entrats: 0, exiters: 6, EP: -4.370311032707373e-05, C_mean: 0.3131092598624174, EP_fact: 0.0023094777292359814
# epoch95, number of firms: 13, entrats: 0, exiters: 0, EP: 0.0001022693789708639, C_mean: 0.3189671341099123, EP_fact: 0.0034680131365187913
# epoch96, number of firms: 13, entrats: 0, exiters: 0, EP: 0.0003273111560064407, C_mean: 0.32705887025086344, EP_fact: 0.0036815615806159827
# epoch97, number of firms: 22, entrats: 9, exiters: 0, EP: 0.0007125788162941117, C_mean: 0.3750602418601396, EP_fact: 0.002059603252114078
# epoch98, number of firms: 34, entrats: 12, exiters: 0, EP: 0.00016757668994550547, C_mean: 0.37730373644083814, EP_fact: 0.0009505993689978313
# epoch99, number of firms: 34, entrats: 0, exiters: 0, EP: 0.0005010654107541715, C_mean: 0.38765358818775886, EP_fact: 0.0008576478978133751
# epoch100, number of firms: 14, entrats: 0, exiters: 20, EP: 0.0001747660124450075, C_mean: 0.3281453407054376, EP_fact: 0.0007110532289609204
# epoch101, number of firms: 14, entrats: 0, exiters: 0, EP: 7.224060804169414e-05, C_mean: 0.3243034299958537, EP_fact: 0.0027120209692206645
# epoch102, number of firms: 12, entrats: 0, exiters: 2, EP: 0.0006205626197236089, C_mean: 0.32895605511388787, EP_fact: 0.0030385740913346526
# epoch103, number of firms: 12, entrats: 0, exiters: 0, EP: 0.0007272040204516586, C_mean: 0.3320826862180193, EP_fact: 0.0036954735348637886
# epoch104, number of firms: 12, entrats: 0, exiters: 0, EP: 0.001351801581738048, C_mean: 0.3482030016972529, EP_fact: 0.004368511823207103
# epoch105, number of firms: 12, entrats: 0, exiters: 0, EP: 0.0009431178169230145, C_mean: 0.33803924745538555, EP_fact: 0.003716915048615863
# epoch106, number of firms: 12, entrats: 0, exiters: 0, EP: 0.0012604358474654284, C_mean: 0.3460397199280869, EP_fact: 0.003746138813378515
# epoch107, number of firms: 12, entrats: 0, exiters: 0, EP: 0.0015865493690608566, C_mean: 0.35351553153207266, EP_fact: 0.004212471355071037
# epoch108, number of firms: 12, entrats: 0, exiters: 0, EP: 0.0027929928064317194, C_mean: 0.3766790452805118, EP_fact: 0.004380435500258232
# epoch109, number of firms: 15, entrats: 3, exiters: 0, EP: 0.0015332267160817524, C_mean: 0.3708425761642354, EP_fact: 0.0026835968950988647
# epoch110, number of firms: 15, entrats: 0, exiters: 0, EP: 0.001457493867598509, C_mean: 0.3691899391977647, EP_fact: 0.0027162535323537735
# epoch111, number of firms: 15, entrats: 0, exiters: 0, EP: 0.001341568924475419, C_mean: 0.36659315199590714, EP_fact: 0.0028299100847692287
# epoch112, number of firms: 15, entrats: 0, exiters: 0, EP: 0.001711593139542238, C_mean: 0.3746087693941521, EP_fact: 0.0030833660236026057
# epoch113, number of firms: 16, entrats: 1, exiters: 0, EP: 0.0014195761967175273, C_mean: 0.3729942110580523, EP_fact: 0.002718323764579554
# epoch114, number of firms: 16, entrats: 0, exiters: 0, EP: 0.001509537650291708, C_mean: 0.3749591499012559, EP_fact: 0.002653960942329798
# epoch115, number of firms: 16, entrats: 0, exiters: 0, EP: 0.0029380010033351837, C_mean: 0.40128676530654467, EP_fact: 0.002503378420121211
# epoch116, number of firms: 31, entrats: 15, exiters: 0, EP: 0.0015974744813394698, C_mean: 0.4103384821536898, EP_fact: 0.0010530937111640824
# epoch117, number of firms: 31, entrats: 0, exiters: 0, EP: 0.001068150530997165, C_mean: 0.3989639496240879, EP_fact: 0.000930976675374936
# epoch118, number of firms: 31, entrats: 0, exiters: 0, EP: 0.0010876421805070748, C_mean: 0.3994153125129647, EP_fact: 0.0010116941909446174
# epoch119, number of firms: 31, entrats: 0, exiters: 0, EP: 0.001136253730021867, C_mean: 0.4005288872838949, EP_fact: 0.0011481484912247892
# epoch120, number of firms: 18, entrats: 0, exiters: 13, EP: 0.0003025674722351784, C_mean: 0.35117122330001377, EP_fact: 0.0009681494579032824
# epoch121, number of firms: 15, entrats: 0, exiters: 3, EP: 0.0005596213709220389, C_mean: 0.34633280868640776, EP_fact: 0.001793041563834149
# epoch122, number of firms: 13, entrats: 0, exiters: 2, EP: 0.000955754923588951, C_mean: 0.34564451719879735, EP_fact: 0.002707880655515295
# epoch123, number of firms: 13, entrats: 0, exiters: 0, EP: 0.0017222814996713668, C_mean: 0.3635138310747564, EP_fact: 0.004123041346403385
# epoch124, number of firms: 14, entrats: 1, exiters: 0, EP: 0.0013747370895525906, C_mean: 0.362028299506035, EP_fact: 0.0035912693399648694
# epoch125, number of firms: 14, entrats: 0, exiters: 0, EP: 0.001331363291722907, C_mean: 0.36103576732600506, EP_fact: 0.003207756419544693
# epoch126, number of firms: 14, entrats: 0, exiters: 0, EP: 0.0011840108609854653, C_mean: 0.3575689448916456, EP_fact: 0.003659514888203264
# epoch127, number of firms: 14, entrats: 0, exiters: 0, EP: 0.001681238558772486, C_mean: 0.3687190732056362, EP_fact: 0.003757603026779408
# epoch128, number of firms: 19, entrats: 5, exiters: 0, EP: 0.0017719768548872068, C_mean: 0.391305163838517, EP_fact: 0.002695879959487283
# epoch129, number of firms: 22, entrats: 3, exiters: 0, EP: 0.0014766996297067613, C_mean: 0.39320962739304816, EP_fact: 0.00205367634804812
# epoch130, number of firms: 22, entrats: 0, exiters: 0, EP: 0.0016531485296728738, C_mean: 0.39684927103453765, EP_fact: 0.0019980844881974553
# epoch131, number of firms: 22, entrats: 0, exiters: 0, EP: 0.002498601951336552, C_mean: 0.41235059564773535, EP_fact: 0.001920780613127513
# epoch132, number of firms: 31, entrats: 9, exiters: 0, EP: 0.0014370459722988227, C_mean: 0.40706882228979474, EP_fact: 0.0012873805843994846
# epoch133, number of firms: 31, entrats: 0, exiters: 0, EP: 0.0010526126649339279, C_mean: 0.39860210775725474, EP_fact: 0.0012395040575394884
# epoch134, number of firms: 15, entrats: 0, exiters: 16, EP: 0.00032252398831374347, C_mean: 0.3388629556252449, EP_fact: 0.0011564063820919443
# epoch135, number of firms: 15, entrats: 0, exiters: 0, EP: 0.0013062243093851914, C_mean: 0.36578440342171514, EP_fact: 0.002995881898451813
# epoch136, number of firms: 15, entrats: 0, exiters: 0, EP: 0.0013062243093851914, C_mean: 0.36578440342171514, EP_fact: 0.002995881898451813
# epoch137, number of firms: 15, entrats: 0, exiters: 0, EP: 0.0014559452071233208, C_mean: 0.3691557924516412, EP_fact: 0.0029196003456506887
# epoch138, number of firms: 15, entrats: 0, exiters: 0, EP: 0.002032291659376, C_mean: 0.3809844660991915, EP_fact: 0.0031033360532106377
# epoch139, number of firms: 18, entrats: 3, exiters: 0, EP: 0.0015336855748341142, C_mean: 0.3831887140123216, EP_fact: 0.002369736432120592
# epoch140, number of firms: 18, entrats: 0, exiters: 0, EP: 0.0012285776105788386, C_mean: 0.3764492516113343, EP_fact: 0.002376149496746558
# epoch141, number of firms: 18, entrats: 0, exiters: 0, EP: 0.0017229884418213269, C_mean: 0.3871016627863708, EP_fact: 0.0023619755532327136
# epoch142, number of firms: 19, entrats: 1, exiters: 0, EP: 0.0010698943062776964, C_mean: 0.37599983042602514, EP_fact: 0.0020610832185685166
# epoch143, number of firms: 19, entrats: 0, exiters: 0, EP: 0.0010230929691537093, C_mean: 0.3748630758818889, EP_fact: 0.0020818552423671048
# epoch144, number of firms: 19, entrats: 0, exiters: 0, EP: 0.0015389041896555298, C_mean: 0.38654494602068756, EP_fact: 0.0023844894070735186
# epoch145, number of firms: 19, entrats: 0, exiters: 0, EP: 0.0015527345648773637, C_mean: 0.38683536234121724, EP_fact: 0.0024007542447226004
# epoch146, number of firms: 19, entrats: 0, exiters: 0, EP: 0.0013247293480085636, C_mean: 0.3819064681718707, EP_fact: 0.0024475157836731432
# epoch147, number of firms: 19, entrats: 0, exiters: 0, EP: 0.0020329783543899947, C_mean: 0.39632895202127594, EP_fact: 0.0024622840201756566
# epoch148, number of firms: 33, entrats: 14, exiters: 0, EP: 0.001302590882015902, C_mean: 0.40640448901719256, EP_fact: 0.001310225345910705
# epoch149, number of firms: 33, entrats: 0, exiters: 0, EP: 0.0010559212231840542, C_mean: 0.4008880170144422, EP_fact: 0.0010964486036403765
# epoch150, number of firms: 16, entrats: 0, exiters: 17, EP: -8.213131936220925e-05, C_mean: 0.3286822514363096, EP_fact: 0.0009397326198138125
# epoch151, number of firms: 14, entrats: 0, exiters: 2, EP: 0.0003420283760355502, C_mean: 0.3339593182242186, EP_fact: 0.002258673869701873
# epoch152, number of firms: 13, entrats: 0, exiters: 1, EP: 0.0005765422888125622, C_mean: 0.33501411853627344, EP_fact: 0.0028295384803796028
# epoch153, number of firms: 13, entrats: 0, exiters: 0, EP: 0.0011691445884364007, C_mean: 0.35102994646666763, EP_fact: 0.003826697974582336
# epoch154, number of firms: 13, entrats: 0, exiters: 0, EP: 0.0017139222335224137, C_mean: 0.36333841141760204, EP_fact: 0.0038368579295709926
# epoch155, number of firms: 16, entrats: 3, exiters: 0, EP: 0.0013280688803987929, C_mean: 0.3709448811203098, EP_fact: 0.003252032436147747
# epoch156, number of firms: 16, entrats: 0, exiters: 0, EP: 0.001372224503423971, C_mean: 0.3719403357800596, EP_fact: 0.003189097654507409
# epoch157, number of firms: 16, entrats: 0, exiters: 0, EP: 0.002116807447074713, C_mean: 0.3871289577919944, EP_fact: 0.0031705679304946943
# epoch158, number of firms: 18, entrats: 2, exiters: 0, EP: 0.0024945478288554822, C_mean: 0.40139893674575144, EP_fact: 0.0030340858104135177
# epoch159, number of firms: 24, entrats: 6, exiters: 0, EP: 0.0014527620364464355, C_mean: 0.39692002148538635, EP_fact: 0.002183530911010112
# epoch160, number of firms: 24, entrats: 0, exiters: 0, EP: 0.0013372191056113926, C_mean: 0.3944428527997374, EP_fact: 0.002004164007084894
# epoch161, number of firms: 24, entrats: 0, exiters: 0, EP: 0.001539876608721479, C_mean: 0.39873672116059106, EP_fact: 0.002026199813629933
# epoch162, number of firms: 24, entrats: 0, exiters: 0, EP: 0.0016936792458826341, C_mean: 0.4018452622993473, EP_fact: 0.0020080981001910883
# epoch163, number of firms: 25, entrats: 1, exiters: 0, EP: 0.001548190622486045, C_mean: 0.40075743258884367, EP_fact: 0.00173698070886082
# epoch164, number of firms: 25, entrats: 0, exiters: 0, EP: 0.0016402684232797015, C_mean: 0.40262325764810475, EP_fact: 0.0016454780857065984
# epoch165, number of firms: 25, entrats: 0, exiters: 0, EP: 0.0014255362508915868, C_mean: 0.3982008475425858, EP_fact: 0.0018550641279466765
# epoch166, number of firms: 25, entrats: 0, exiters: 0, EP: 0.001752421834862046, C_mean: 0.40483818699067375, EP_fact: 0.0018707746630206024
# epoch167, number of firms: 31, entrats: 6, exiters: 0, EP: 0.0018100979247599501, C_mean: 0.41447065745628014, EP_fact: 0.0010221766722653628
# epoch168, number of firms: 36, entrats: 5, exiters: 0, EP: 0.001502994957101141, C_mean: 0.4134093341140892, EP_fact: 0.0006697264455715847
# epoch169, number of firms: 36, entrats: 0, exiters: 0, EP: 0.0013742916527755495, C_mean: 0.4107528914220557, EP_fact: 0.0008159749764403295
# epoch170, number of firms: 36, entrats: 0, exiters: 0, EP: 0.0013624291060250304, C_mean: 0.4105032594697967, EP_fact: 0.0009637488170282061
# epoch171, number of firms: 36, entrats: 0, exiters: 0, EP: 0.0014555209071585164, C_mean: 0.41244030661034536, EP_fact: 0.0009054025179970228
# epoch172, number of firms: 36, entrats: 0, exiters: 0, EP: 0.0014087519555604508, C_mean: 0.41147338031545394, EP_fact: 0.0010664226945360027
# epoch173, number of firms: 17, entrats: 0, exiters: 19, EP: 0.00028967433082865393, C_mean: 0.3469252043389142, EP_fact: 0.0007283873142848521
# epoch174, number of firms: 15, entrats: 0, exiters: 2, EP: 0.0006729287923947201, C_mean: 0.34963633058135674, EP_fact: 0.0019079420389846043
# epoch175, number of firms: 15, entrats: 0, exiters: 0, EP: 0.0011194618772372325, C_mean: 0.36136772357317765, EP_fact: 0.002645538056769796
# epoch176, number of firms: 14, entrats: 0, exiters: 1, EP: 0.0008252653195083444, C_mean: 0.34842066156017787, EP_fact: 0.0025676819993045675
# epoch177, number of firms: 14, entrats: 0, exiters: 0, EP: 0.0018387137956039708, C_mean: 0.37195952301020013, EP_fact: 0.0031160474809190366
# epoch178, number of firms: 16, entrats: 2, exiters: 0, EP: 0.0015857144419351194, C_mean: 0.37658660326274035, EP_fact: 0.0026356852398758297
# epoch179, number of firms: 16, entrats: 0, exiters: 0, EP: 0.0015485290419269908, C_mean: 0.3757962206408082, EP_fact: 0.0028296379945978185
# epoch180, number of firms: 16, entrats: 0, exiters: 0, EP: 0.0015485290419269908, C_mean: 0.3757962206408082, EP_fact: 0.0028296379945978185
# epoch181, number of firms: 16, entrats: 0, exiters: 0, EP: 0.0016562342579865687, C_mean: 0.37806494746773767, EP_fact: 0.0026786774228549524
# epoch182, number of firms: 16, entrats: 0, exiters: 0, EP: 0.0021638877667482987, C_mean: 0.3880038417566619, EP_fact: 0.002826984598203657
# epoch183, number of firms: 14, entrats: 4, exiters: 6, EP: 0.0005715377798318291, C_mean: 0.3411975965629714, EP_fact: 0.0019201871643190504
# epoch184, number of firms: 13, entrats: 0, exiters: 1, EP: 0.0008206547575057644, C_mean: 0.34202919898928447, EP_fact: 0.0031676338476152753
# epoch185, number of firms: 13, entrats: 0, exiters: 0, EP: 0.0015515992667472275, C_mean: 0.35985822451134813, EP_fact: 0.003535802255007762
# epoch186, number of firms: 13, entrats: 0, exiters: 0, EP: 0.003744738432198572, C_mean: 0.3983449435600375, EP_fact: 0.003505531738171172
# epoch187, number of firms: 22, entrats: 9, exiters: 0, EP: 0.0015058512701794152, C_mean: 0.39382260645690487, EP_fact: 0.0018156387379292258
# epoch188, number of firms: 22, entrats: 0, exiters: 0, EP: 0.0010990708194280959, C_mean: 0.3847946568575379, EP_fact: 0.0017559634814252115
# epoch189, number of firms: 22, entrats: 0, exiters: 0, EP: 0.001133711049572085, C_mean: 0.38560670781316214, EP_fact: 0.001974792493950076
# epoch190, number of firms: 22, entrats: 0, exiters: 0, EP: 0.001618930364301482, C_mean: 0.3961563455081318, EP_fact: 0.0019079598373581224
# epoch191, number of firms: 22, entrats: 0, exiters: 0, EP: 0.0016554766760396135, C_mean: 0.39689619953074806, EP_fact: 0.0018870077621735725
# epoch192, number of firms: 22, entrats: 0, exiters: 0, EP: 0.0015017435107374617, C_mean: 0.39373652029941525, EP_fact: 0.0017881712294494387
# epoch193, number of firms: 22, entrats: 0, exiters: 0, EP: 0.0011479194009718875, C_mean: 0.3859372443761251, EP_fact: 0.0018280617518189853
# epoch194, number of firms: 22, entrats: 0, exiters: 0, EP: 0.001280514256597249, C_mean: 0.38895381218245456, EP_fact: 0.0018952840716398398
# epoch195, number of firms: 22, entrats: 0, exiters: 0, EP: 0.001088209044771058, C_mean: 0.38453819208339246, EP_fact: 0.001824480804000293
# epoch196, number of firms: 22, entrats: 0, exiters: 0, EP: 0.0012352061240105874, C_mean: 0.3879365163077722, EP_fact: 0.0016810271184123928
# epoch197, number of firms: 22, entrats: 0, exiters: 0, EP: 0.0017185816636505554, C_mean: 0.3981578941281816, EP_fact: 0.0016920957333165009
# epoch198, number of firms: 25, entrats: 3, exiters: 0, EP: 0.0020157706498769505, C_mean: 0.40981237537848986, EP_fact: 0.0015078255877530252
# epoch199, number of firms: 28, entrats: 3, exiters: 0, EP: 0.0014854063781341406, C_mean: 0.40422547206077336, EP_fact: 0.0016049528193064781
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# ...
#
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.2
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\1158626001.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.2

# %%
result2 = Noke.getData()
result2
# Out:
#      param_0  param_1  sigma  S      f    ef     r  alpha   NPV_ent  n_firms  \
# 0        0.3      0.5    0.5  4  0.001  0.01  0.02    0.8  0.009654       61
# 1        0.3      0.5    0.5  4  0.001  0.01  0.02    0.8  0.009678       61
# 2        0.3      0.5    0.5  4  0.001  0.01  0.02    0.8  0.008499       94
# 3        0.3      0.5    0.5  4  0.001  0.01  0.02    0.8  0.009315       14
# 4        0.3      0.5    0.5  4  0.001  0.01  0.02    0.8 -0.005771       14
# ..       ...      ...    ... ..    ...   ...   ...    ...       ...      ...
# 195      0.3      0.5    0.5  4  0.001  0.01  0.20    0.8  0.007683       22
# 196      0.3      0.5    0.5  4  0.001  0.01  0.20    0.8  0.006529       22
# 197      0.3      0.5    0.5  4  0.001  0.01  0.20    0.8  0.007411       22
# 198      0.3      0.5    0.5  4  0.001  0.01  0.20    0.8  0.008948       25
# 199      0.3      0.5    0.5  4  0.001  0.01  0.20    0.8  0.009420       28
#
#       Pr_mean        EP    C_mean    Sigma2  n_entr  n_ext
# 0    0.000255  0.000190  0.393343  0.412602      51      0
# 1    0.000360  0.000342  0.398092  0.417200       0      0
# 2    0.000347  0.000183  0.399875  0.412377      33      0
# 3    0.000109 -0.000113  0.316681  0.402096       0     80
# 4    0.003643  0.000411  0.336224  0.419196       0      0
# ..        ...       ...       ...       ...     ...    ...
# 195  0.001824  0.001088  0.384538  0.435827       0      0
# 196  0.001681  0.001235  0.387937  0.438942       0      0
# 197  0.001692  0.001719  0.398158  0.448311       0      0
# 198  0.001508  0.002016  0.409812  0.453530       3      0
# 199  0.001605  0.001485  0.404225  0.443944       3      0
#
# [200 rows x 16 columns]

# %%
plt.figure(figsize=(10,5))
plt.subplot(2,1,1)
plt.title('n_firms')
plt.plot(result2["n_firms"])
plt.subplot(2,1,2)
plt.title('Mean C')
plt.plot(result2["C_mean"])

# %%
#СТАВОЧКУ НА РОДИНУ

for i in range(100, 200):
    df["r"][i] = 0.02
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# ...
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["r"][i] = 0.02
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2385421624.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["r"][i] = 0.02

# %%
#ШОК КОСТОВ

for i in range(100, 200):
    df["f"][i] = 0.002

Noke.setData(df)
Noke.scenario(out = False)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# ...
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.002
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\468035543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.002

# %%
plt.figure(figsize=(10,5))
plt.subplot(2,1,1)
plt.title('n_firms')
plt.plot(result2["n_firms"])
plt.subplot(2,1,2)
plt.title('Mean C')
plt.plot(result2["C_mean"])

# %%
#КОСТЫ НА РОДИНУ

for i in range(100, 200):
    df["f"][i] = 0.001
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["f"][i] = 0.001
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2304676190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["f"][i] = 0.001

# %%
#ШОК КОСТОВ ВХОДА

for i in range(100, 200):
    df["ef"][i] = 0.05

Noke.setData(df)
Noke.scenario(out = False)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.05
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2251964738.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.05

# %%
plt.figure(figsize=(10,5))
plt.subplot(2,1,1)
plt.title('n_firms')
plt.plot(result2["n_firms"])
plt.subplot(2,1,2)
plt.title('Mean C')
plt.plot(result2["C_mean"])

# %%
#ШОК КОСТОВ ВХОДА НА РОДИНУ

for i in range(100, 200):
    df["ef"][i] = 0.1


# ТЕХНОШОК
for i in range(100, 200):
    df["param_0"][i] = 0.1
    df["param_1"][i] = 0.3

df
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ef"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["ef"][i] = 0.1
# ...
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_0"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_0"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_1"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_1"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_0"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_0"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_1"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_1"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_0"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_0"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_1"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_1"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_0"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_0"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_1"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_1"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_0"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_0"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_1"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_1"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_0"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_0"][i] = 0.1
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_1"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\3370765154.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_1"][i] = 0.3
#      param_0  param_1  sigma  S      f    ef     r  alpha   NPV_ent  n_firms  \
# 0        0.3      0.5    0.5  4  0.001  0.01  0.02    0.8  0.009948      126
# 1        0.3      0.5    0.5  4  0.001  0.01  0.02    0.8  0.009765      140
# 2        0.3      0.5    0.5  4  0.001  0.01  0.02    0.8  0.007429      140
# 3        0.3      0.5    0.5  4  0.001  0.01  0.02    0.8  0.009892       22
# 4        0.3      0.5    0.5  4  0.001  0.01  0.02    0.8 -0.033273       13
# ..       ...      ...    ... ..    ...   ...   ...    ...       ...      ...
# 195      0.1      0.3    0.5  4  0.001  0.10  0.02    0.8  0.022538       26
# 196      0.1      0.3    0.5  4  0.001  0.10  0.02    0.8  0.049822       26
# 197      0.1      0.3    0.5  4  0.001  0.10  0.02    0.8  0.031506       26
# 198      0.1      0.3    0.5  4  0.001  0.10  0.02    0.8  0.016870       26
# 199      0.1      0.3    0.5  4  0.001  0.10  0.02    0.8  0.024835       26
#
#       Pr_mean        EP    C_mean    Sigma2  n_entr  n_ext
# 0    0.000161  0.000281  0.406123  0.415403     116      0
# 1    0.000025  0.000146  0.402782  0.411193      14      0
# 2    0.000042  0.000259  0.406390  0.414751       0      0
# 3   -0.000372 -0.000652  0.317872  0.374716      90    208
# 4    0.001951 -0.000044  0.313098  0.404685       0      9
# ..        ...       ...       ...       ...     ...    ...
# 195  0.001862  0.000977  0.389782  0.433369       0      0
# 196  0.001374  0.000618  0.380497  0.424747       0      0
# 197  0.001257  0.000331  0.372031  0.416886       0      0
# 198  0.001284  0.000487  0.376775  0.421291       0      0
# 199  0.001306  0.000556  0.378753  0.423128       0      0
#
# [200 rows x 16 columns]

# %%
Noke.setData(df)
Noke.scenario(out = False)

# %%
plt.figure(figsize=(10,5))
plt.subplot(2,1,1)
plt.title('n_firms')
plt.plot(result2["n_firms"])
plt.subplot(2,1,2)
plt.title('Mean C')
plt.plot(result2["C_mean"])

# %%
# ТЕХНОШОК НА РОДИНУ
for i in range(100, 200):
    df["param_0"][i] = 0.3
    df["param_1"][i] = 0.5

# ШОК СПРОСА

for i in range(100, 200):
    df["S"][i] = 6

df
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_1"][i] = 0.5
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_1"][i] = 0.5
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_1"][i] = 0.5
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_1"][i] = 0.5
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_1"][i] = 0.5
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_1"][i] = 0.5
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_1"][i] = 0.5
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_1"][i] = 0.5
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_1"][i] = 0.5
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_1"][i] = 0.5
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_1"][i] = 0.5
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_1"][i] = 0.5
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_1"][i] = 0.5
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_1"][i] = 0.5
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_1"][i] = 0.5
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_1"][i] = 0.5
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_1"][i] = 0.5
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_1"][i] = 0.5
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_1"][i] = 0.5
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_1"][i] = 0.5
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_1"][i] = 0.5
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_1"][i] = 0.5
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_1"][i] = 0.5
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_1"][i] = 0.5
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_1"][i] = 0.5
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_1"][i] = 0.5
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_1"][i] = 0.5
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_1"][i] = 0.5
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_1"][i] = 0.5
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_1"][i] = 0.5
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_1"][i] = 0.5
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_1"][i] = 0.5
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_1"][i] = 0.5
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_1"][i] = 0.5
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_1"][i] = 0.5
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_1"][i] = 0.5
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_1"][i] = 0.5
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_1"][i] = 0.5
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["param_0"][i] = 0.3
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# ...
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["S"][i] = 6
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["S"][i] = 6
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["S"][i] = 6
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["S"][i] = 6
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["S"][i] = 6
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["S"][i] = 6
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["S"][i] = 6
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["S"][i] = 6
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["S"][i] = 6
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["S"][i] = 6
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["S"][i] = 6
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["S"][i] = 6
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["S"][i] = 6
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["S"][i] = 6
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["S"][i] = 6
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["S"][i] = 6
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["S"][i] = 6
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["S"][i] = 6
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["S"][i] = 6
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["S"][i] = 6
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["S"][i] = 6
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["S"][i] = 6
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["S"][i] = 6
# C:\Users\user\AppData\Local\Temp\ipykernel_18440\2562943351.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["S"][i] = 6
#      param_0  param_1  sigma  S      f    ef     r  alpha   NPV_ent  n_firms  \
# 0        0.3      0.5    0.5  4  0.001  0.01  0.02    0.8  0.009549       63
# 1        0.3      0.5    0.5  4  0.001  0.01  0.02    0.8  0.009969       81
# 2        0.3      0.5    0.5  4  0.001  0.01  0.02    0.8  0.009922       91
# 3        0.3      0.5    0.5  4  0.001  0.01  0.02    0.8  0.006184       14
# 4        0.3      0.5    0.5  4  0.001  0.01  0.02    0.8 -0.009204       14
# ..       ...      ...    ... ..    ...   ...   ...    ...       ...      ...
# 195      0.3      0.5    0.5  6  0.001  0.10  0.02    0.8  0.069809       43
# 196      0.3      0.5    0.5  6  0.001  0.10  0.02    0.8  0.064220       43
# 197      0.3      0.5    0.5  6  0.001  0.10  0.02    0.8  0.061967       43
# 198      0.3      0.5    0.5  6  0.001  0.10  0.02    0.8  0.071684       43
# 199      0.3      0.5    0.5  6  0.001  0.10  0.02    0.8  0.080837       43
#
#       Pr_mean        EP    C_mean    Sigma2  n_entr  n_ext
# 0    0.000246  0.000361  0.399275  0.417759      53      0
# 1    0.000316  0.000312  0.401913  0.416325      18      0
# 2    0.000228  0.000121  0.397440  0.410398      10      0
# 3    0.000035 -0.000180  0.313651  0.399444       0     77
# 4    0.003241  0.000328  0.333492  0.416806       0      0
# ..        ...       ...       ...       ...     ...    ...
# 195  0.001001  0.001259  0.204063  0.239438       0      0
# 196  0.000917  0.001215  0.203105  0.238522       0      0
# 197  0.001023  0.001406  0.207148  0.242386       0      0
# 198  0.001204  0.001585  0.210765  0.245842       0      0
# 199  0.001400  0.001647  0.211969  0.246992       0      0
#
# [200 rows x 16 columns]

# %%
Noke.setData(df)
Noke.scenario(out = False)

# %%
plt.figure(figsize=(10,5))
plt.subplot(2,1,1)
plt.title('n_firms')
plt.plot(result2["n_firms"])
plt.subplot(2,1,2)
plt.title('Mean C')
plt.plot(result2["C_mean"])
